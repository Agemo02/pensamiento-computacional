# %% [markdown]
# <a href="https://colab.research.google.com/gist/Agemo02/d4adedb3986ffd37626e489ee92b3c96/a00834829_entrega1proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Daniel Peña Ortiz
#
# A00834829
#
# Pensamiento computacional para la ingenieria
#
# German Dominguez
#
# Sabado 27
#
# Enlace: https://colab.research.google.com/drive/1YGOmnpWXzET91bvaSGjuXjpj2tg8Pq3c?usp=sharing

# %% [markdown]
# Situacion problema: hay un programa que evalua la capacidad de los alumnos de 15 años en las areas de lectura, matematicas y ciencias, esta evaluacion internacional de la OCDE es aplicada cada 3 años pero los alumnos del año 2018 los estudiantes mexicanos obtuvieron un puntaje por debajo del promedio de los paises que pertenecen a la OCDE y un tercer lugar en los paises de america latina, las graficas y los datos representan que hay un escaso avance y aunque muchas cosas si han mejorado, nos falta muhco para mejorar la educaccion en mexico.
#
# Yo creo que con un programa nos puede ayudar a que las alumnas y alumnos lo puedan acceder el momento que quieran a practicar, podria arrojar resultados de manera instantanea, podria dar recomendaciones en las areas que se salio mas bajo entre otras cosas mas maravillosas, un codigo asi podria ser utilizado por muchas personas, especialmente nuestro grupo enfocado que serian los que tomaran el PISA, al realizar un programa de este tipo no solo sirve para ayudar a los alumnos sino que tambien mejora nuestro pensamiento computacional, se implementa absolutamente todo lo que hemos visto durante el primer y segundo periodo, y se pone en practica, al mismo tiempo que se va a aprendiendo de nuestros propios errores

# %%
#preguntas = [
#      ['1', 'Matemáticas', 'Texto de la pregunta', 'R1', 'R2', 'R3', 'R4', 'RC' ],
#      ['2', 'Lectura', 'Texto de la pregunta', 'R1', 'R2', 'R3', 'R4', 'RC' ],
#      ['3', 'Ciencias', 'Texto de la pregunta', 'R1', 'R2', 'R3', 'R4', 'RC' ]]



import time
preguntas=[['1', 'Matematicas', '4*3', 'Respuesta 1: 7', 'Respuesta 2: 1', 'Respuesta 3: 12', 'Respuesta 4: 5', '12'], ['2', 'Matematicas', '3+3-4', 'Respuesta 1: 2', 'Respuesta 2: 10', 'Respuesta 3: 1', 'Respuesta 4: 3', '2'], ['3', 'Matematicas', 'sqrt(9)', 'Respuesta 1: 81', 'Respuesta 2: 18', 'Respuesta 3: 3', 'Respuesta 4: 27', '3'], ['4', 'Lectura', 'que año termino la segunda guerra mundial?', 'Respuesta 1: 1944', 'Respuesta 2: 1945', 'Respuesta 3: 1943', 'Respuesta 4: 1940', '1945'], ['5', 'Lectura', 'que año comenzo la segunda guerra mundial?', 'Respuesta 1: 1933', 'Respuesta 2: 1932', 'Respuesta 3: 1938', 'Respuesta 4: 1939', '1939'], ['6', 'Lectura', 'que año sucedio el grito por la indepencia?', 'Respuesta 1: 1810', 'Respuesta 2: 1903', 'Respuesta 3: 1800', 'Respuesta 4: 1945', '1810'], ['7', 'Ciencias', 'a que temperatura hierve el agua', 'Respuesta 1: 0 celcius', 'Respuesta 2: 300 celcius', 'Respuesta 3: 233 celcius', 'Respuesta 4: 100 celcius', '100 celcius'], ['8', 'Ciencias', 'cual es la velocidad del sonido', 'Respuesta 1: 1000 m/S', 'Respuesta 2: 300 m/s', 'Respuesta 3: 343 m/s', 'Respuesta 4: 1,000,000 m/s', '343 m/s'], ['9', 'Ciencias', 'cual es la formula quimica del agua', 'Respuesta 1: H+O', 'Respuesta 2: H2O', 'Respuesta 3: H', 'Respuesta 4: O', 'H2O'], ['10', 'Ciencias', 'quien es el padre de la evolucion', 'Respuesta 1: darwin', 'Respuesta 2: einstein', 'Respuesta 3: pascal', 'Respuesta 4: jorge', 'darwin']]
respuestas_correctas = 0
respuestas_incorrectas = 0
lista_notas = []

def reporte_calificaciones():
  global preguntas
  global respuesta_correcta
  global lista_notas
  print("Bienvenido a la opcion de reporte de calificaciones ")
  usuarios = len(lista_notas)

  suma = 0
  for nota in lista_notas:
    suma = suma + nota 
  promedio = suma / len(lista_notas)

  porcentaje_correcto = round(respuestas_correctas / (respuestas_correctas + respuestas_incorrectas) * 100, 2)
  porcentaje_incorrectas = round(respuestas_incorrectas / (respuestas_correctas + respuestas_incorrectas) * 100, 2)

  print(f'{"Total de usuarios":<30}{usuarios}\n{"Promedio de calificaciones":<30}{promedio}\n{"Respuestas correctas":<30}{porcentaje_correcto}%\n{"Repuestas incorrectas":<30}{porcentaje_incorrectas}%')


def presentar_quiz():
  global preguntas
  global respuestas_correctas
  global respuestas_incorrectas
  print("Bienvenido a la opcion de presentar un quiz, a continuacion se le pedira que conteste estas 10 preguntas, ingrese la opcion correcta")
  for i in range(10):

    pregunta = preguntas[i]
    id, tema, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta #asignacion multiple

    if tema == 1:
      tema = "Lectura"
    elif tema == 2:
      tema = "Matematicas"
    else:
      tema = "Ciencias"
    print(f'{texto_pregunta}\n{respuesta1:<20}{respuesta2:<20}{respuesta3:<20}{respuesta4}\n')
    respuesta = input("Ingrese la respuesta correcta por favor: ")
    if respuesta == correcta:
      respuestas_correctas += 1
    else:
      respuestas_incorrectas += 1

    calificacion = respuestas_correctas * 10 
    print(f"Tu calificacion es: {calificacion}")
    lista_notas.append(calificacion)

def estudiar_preguntas():
  global preguntas
  print("Bienvenido a la opcion de el estudio de area")
  contador = 0
  quiz_area = input("Ingrese el area que desea estudiar: ")
  for pregunta in preguntas:
    if pregunta[1] == quiz_area:
      contador += 1

  while True:
    num_preguntas = int(input("Ingrese la cantidad de preguntas que desea contestar: "))
    if num_preguntas <= contador:
      break
  respuestas = []
  for i in range(num_preguntas):
    print(f"Pregunta {preguntas[i][0]}\n Pregunta: {preguntas[i][2]}\nRespuestas{preguntas[i][3]}")
    respuesta = int(input("Ingrese la respuesta correcta: "))
    respuestas.append(respuesta)




def actualizar_pregunta():

  global preguntas # el global sirve para tener (preguntas) en cualquier parte del programa

  print("Bienvenido a la opcion para actualizar preguntas ")
  
  for pregunta in preguntas:
   
    print(preguntas)

  while True:

    id_pregunta = int(input("Ingrese el id de la pregunta "))
    
    if id_pregunta <= int(preguntas[-1][0]): #validar que el id exista

      break
  
  
  tema = input("De que tema quieres que sea tu pregunta , puede ser Matematicas, lectura, ciencias?: ")
  if tema == "":
    tema = preguntas[id_pregunta - 1][1]
  pregunta = input("Ingresa la pregunta: ")
  if pregunta == "":
    pregunta = preguntas[id_pregunta - 1][2] 
  respuestas = ""
   

  for num in range(4): 
      respuesta = input("Ingresa la respuesta " + str(num + 1) + ": ")

      if num == 3:
        respuestas = respuestas + "Respuesta " + str(num + 1) + ": " + respuesta 
      else:
        respuestas = respuestas + "Respuesta " + str(num + 1) + ": " + respuesta + ", "

  respuestas= respuestas.split(", ") #hacer que la lista se haga string, cada elemento sera separado por una coma

  respuesta1, respuesta2, respuesta3, respuesta4 = respuestas  
  for i in range(len(respuestas)):
    if respuestas[i] == "Respuesta " + str(i + 1) + ": ":
    
      respuestas[i] = preguntas[id_pregunta - 1][3][i]

  respuesta_correcta = input("Ingresa la respuesta correcta: ")
  if respuesta_correcta == "": # si no lo desean cambiar, simplemente ponen espacio
    respuesta_correcta = preguntas[id_pregunta - 1][4]



  print(f"Pregunta registrada\n Tema o area de la pregunta es: {tema}\n Pregunta: {pregunta}\nRespuestas{respuestas}\nLa respuesta correcta es{respuesta_correcta}")    
  pregunta = [id_pregunta, tema, pregunta, respuestas, respuesta_correcta]

  cambio_pregunta = input("¿Está seguro de que quiere actualizar los datos de la pregunta? ")
  if cambio_pregunta == "Si":
    

    preguntas[id_pregunta - 1] = pregunta

def menu():
  print(
      
    """Menu de opciones
      
    1. Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
    2. Actualizar preguntas de la prueba PISA (lectura, matemáticas, ciencias)
    3. Estudiar preguntas de cierta área (lectura, matemáticas, ciencias)
    4. Presentar un quiz (lectura, matemáticas, ciencias)
    5. Reporte de calificaciones
    6. Salir"""
  )
  opcion =int(input("Ingresa una opcion valida: "))
  return opcion



def registrar_pregunta():

  global preguntas

  print("Esta es la opcion para registrar la preguntas, bienvenido")
  id_pregunta = input("Ingresa el id de la pregunta: ")
  tema = input("De que tema quieres que sea tu pregunta , puede ser Matematicas, lectura, ciencias?: ")
  pregunta = input("Ingresa la pregunta: ")
  respuestas = ""

#registrar 4 opciones multiple para el examen 
  for num in range(4):
      respuesta = input("Ingresa la respuesta " + str(num + 1) + ": ")

      if num == 3:
        respuestas = respuestas + "Respuesta " + str(num + 1) + ": " + respuesta 
      else:
        respuestas = respuestas + "Respuesta " + str(num + 1) + ": " + respuesta + ", "
#De las 4 opciones multiples se registrara la correcta de estas
  respuestas= respuestas.split(", ") #hacer que la lista se haga string, cada elemento sera separado por una coma

  respuesta1, respuesta2, respuesta3, respuesta4 = respuestas #asignacion multiple

  respuesta_correcta = input("Ingresa la respuesta correcta: ")

  pregunta = [id_pregunta, tema, pregunta, respuesta1, respuesta2, respuesta3, respuesta4, respuesta_correcta]

  print(f"Pregunta registrada\n Tema o area de la pregunta es: {tema}\n Pregunta: {pregunta}\nRespuestas{respuestas}\nLa respuesta correcta es{respuesta_correcta}\n")

  preguntas.append(pregunta)
  print(preguntas)





def salir():
  print("Gracias por utlizar el programa ")

def main():
  while True:
    opcion = menu()

    if opcion < 1 or opcion > 6:
      print("Error, por favor seleccione una opcion valida entre 1 y 6")
      continue
    elif opcion == 1:
      registrar_pregunta()
    elif opcion == 2:
      actualizar_pregunta()
    elif opcion == 3:
      estudiar_preguntas()
    elif opcion == 4:
      presentar_quiz()
    elif opcion == 5:
      reporte_calificaciones()
    elif opcion ==6:
      salir()
      break




main()
# Out:
# Menu de opciones
#
#     1. Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
#     2. Actualizar preguntas de la prueba PISA (lectura, matemáticas, ciencias)
#     3. Estudiar preguntas de cierta área (lectura, matemáticas, ciencias)
#     4. Presentar un quiz (lectura, matemáticas, ciencias)
#     5. Reporte de calificaciones
#     6. Salir
# Ingresa una opcion valida: 0
# Error, por favor seleccione una opcion valida entre 1 y 6
# Menu de opciones
#
#     1. Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
#     2. Actualizar preguntas de la prueba PISA (lectura, matemáticas, ciencias)
#     3. Estudiar preguntas de cierta área (lectura, matemáticas, ciencias)
#     4. Presentar un quiz (lectura, matemáticas, ciencias)
#     5. Reporte de calificaciones
#     6. Salir
# Ingresa una opcion valida: 7
# Error, por favor seleccione una opcion valida entre 1 y 6
# Menu de opciones
#
# ...

# %% [markdown]
# ### Reflexion

# %% [markdown]
# este proyecto la verdad siendo 100% sincero estuvo complicado, yo me considero alguien que no es muy bueno en la programacion, las cosas no se me dan naturalmente, fui varias veces a asesoria con profesores, y con personas que le saben mas al tema, pero al final del dia me siento satisfecho,aprendi como funcionan las listas, que partes deben de ir en el codigo que no debe de ir, las cosas deben de tener un orden, a veces un problema que esta ocurriendo es un simple borrar de un caracter, algo mas indentado, una palabra mal escrita, la programacion es exacta, no es algo que puedas escribir algo mal y que de una manera u otra salga bien, aprendi que debo de tratar de mejorar en la programacion ya que no es mi fuerte, siento que si hice mi codigo bien, en alguna parte u otra puede mejorar pero la funcionalidad esta ahi y hace lo que me pide, algo que puedo mejorar seria a lo mejor practicar mas yo por mi cuenta, muchas veces me rindo muy facil y simplemente digo que no puedo hacerlo solo, cuando no es algo que me apasiona me desacredito y siento que soy pesimo, porque me comparo mucho con el progreso de los demas, quisiera ser perfecto al programar, pero me di cuenta que la perfeccion se trabaja, y si hay gente que nace con el don yo simplemente trabajare mas duro que ellos porque asi me toco y no me puedo quejar y quedarme atras
